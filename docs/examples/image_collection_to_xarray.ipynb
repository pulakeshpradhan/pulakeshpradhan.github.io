# %% [markdown]
# # Image Collection to xarray
#
# In this tutorial, we'll look at how we can use `wxee` and the `wx` accessor to convert an `ee.ImageCollection` of gridMET weather data to an `xarray.Dataset` for visualization and further processing.

# %% [markdown]
# ## Setup

# %%
# !pip install wxee

# %%
import ee
import wxee

ee.Authenticate()
wxee.Initialize()
# Out:
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=thAU9JwT1qhNix7Sqb3WQj_G5nUxiQrnT74vEe-BgfE&tc=z-fMJKGGqMX54bZYo2hy4o9dqOJ0kL2odD1cEhn39Jw&cc=JJ7MzF01pJIfvvH7_2ByPoVnoEt1hOXMQZ0N266aNiE
#
# The authorization workflow will generate a code, which you should paste in the box below.
# Enter verification code: 4/1AfJohXl-xoLNrG4-8e5jQaHRUxzTyCEE5iAUEuJSYVvppEXmbOpF-fBRQPg
#
# Successfully saved authorization token.

# %% [markdown]
# ## Converting to xarray

# %% [markdown]
# Load the gridMET image collection.

# %%
gridmet = ee.ImageCollection("IDAHO_EPSCOR/GRIDMET")

# %% [markdown]
# Select a date range of the collection to download to xarray. gridMET has 1 image per day, so this will give us 6 images.

# %%
collection = gridmet.filterDate("2020-09-05", "2020-09-11")

# %% [markdown]
# Set the download parameters. We'll use the full gridMET image extent of the continental US, but if we wanted to select a specific region we could pass an `ee.Geometry.Polygon` to the `region` argument.

# %%
# The coordinate reference system to use (NAD83 Albers CONUS)
crs = "EPSG:5070"
# Spatial resolution in CRS units (meters)
scale = 20_000

# %% [markdown]
# The `wx` accessor extends images and image collections with additional functionality including `to_xarray`. We'll use that to download the collection, storing it in memory as an `xarray.Dataset`.

# %%
arr = collection.wx.to_xarray(scale=scale, crs=crs)
# Out:
# Requesting data:   0%|          | 0/6 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0/6 [00:00<?, ?it/s]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Tip:</b> If the download fails due to a DownloadError, retry or increase the max_attempts argument.
# </div>

# %% [markdown]
# The downloaded array has 6 time coordinates (1 for each image) and 16 variables (1 for each band).

# %%
arr
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 6, x: 292, y: 154)
# Coordinates:
#   * time         (time) datetime64[ns] 2020-09-05T06:00:00 ... 2020-09-10T06:...
#   * x            (x) float64 -2.91e+06 -2.89e+06 -2.87e+06 ... 2.89e+06 2.91e+06
#   * y            (y) float64 3.27e+06 3.25e+06 3.23e+06 ... 2.3e+05 2.1e+05
#     spatial_ref  int64 0
# Data variables: (12/16)
#     pr           (time, y, x) float32 nan nan nan nan nan ... nan nan nan nan
#     rmax         (time, y, x) float32 nan nan nan nan nan ... nan nan nan nan
#     rmin         (time, y, x) float32 nan nan nan nan nan ... nan nan nan nan
#     sph          (time, y, x) float32 nan nan nan nan nan ... nan nan nan nan
#     srad         (time, y, x) float32 nan nan nan nan nan ... nan nan nan nan
#     th           (time, y, x) float32 nan nan nan nan nan ... nan nan nan nan
#     ...           ...
#     eto          (time, y, x) float32 nan nan nan nan nan ... nan nan nan nan
#     bi           (time, y, x) float32 nan nan nan nan nan ... nan nan nan nan
#     fm100        (time, y, x) float32 nan nan nan nan nan ... nan nan nan nan
#     fm1000       (time, y, x) float32 nan nan nan nan nan ... nan nan nan nan
#     etr          (time, y, x) float32 nan nan nan nan nan ... nan nan nan nan
#     vpd          (time, y, x) float32 nan nan nan nan nan ... nan nan nan nan
# Attributes:
#     AREA_OR_POINT:           Area
#     TIFFTAG_RESOLUTIONUNIT:  1 (unitless)
#     TIFFTAG_XRESOLUTION:     1
#     TIFFTAG_YRESOLUTION:     1
#     _FillValue:              -32768.0
#     scale_factor:            1.0
#     add_offset:              0.0

# %% [markdown]
# ## Visualizing

# %% [markdown]
# Let's calculate the max wind velocity over the time dimension and plot it.

# %%
arr.vs.max("time").plot(figsize=(10, 5), cmap="magma")

# %% [markdown]
# Going a little further, let's calculate the Hot-Dry-Windy (HDW) index and see how it changed over the 6 days.

# %%
hdw = arr.vs * arr.vpd

hdw.plot(col="time", col_wrap=3, cmap="magma", figsize=(15, 6))
